# %%
import os
import shutil
from pdf2image import convert_from_path
import boto3
from tqdm.notebook import tqdm
import cv2
import re

import io

# %%
class process_pdf_csv():
    def __init__(self):
        pass

    def create_pdf_image(self, output_path, **kwargs):
        if not os.path.exists(output_path):
            os.makedirs(output_path)
        else:
            shutil.rmtree(output_path, ignore_errors=True)
            os.makedirs(output_path)
        self.images_list = convert_from_path(**kwargs, output_folder = output_path)
        for idx, file_path in enumerate(self.images_list):
            directory = os.path.dirname(file_path)
            filename = os.path.basename(file_path)

            if filename.endswith('.jpg'):
                original_number = filename.split('-')[-1].split('.')[0]
                new_filename = original_number + '.jpg'
                old_filepath = file_path
                new_filepath = os.path.join(directory, new_filename)
                os.rename(old_filepath, new_filepath)
                self.images_list[idx] = new_filepath

        return self.images_list

    def get_rows_columns_map(self, table_result, blocks_map):
        rows = {}
        for relationship in table_result['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    cell = blocks_map[child_id]
                    if cell['BlockType'] == 'CELL':
                        row_index = cell['RowIndex']
                        col_index = cell['ColumnIndex']
                        if row_index not in rows:
                            rows[row_index] = {}

                        rows[row_index][col_index] = self.get_text(cell, blocks_map)
        return rows

    def get_text(self, result, blocks_map):
        text = ''
        if 'Relationships' in result:
            for relationship in result['Relationships']:
                if relationship['Type'] == 'CHILD':
                    for child_id in relationship['Ids']:
                        word = blocks_map[child_id]
                        if word['BlockType'] == 'WORD':
                            text += word['Text'] + ' '
                        if word['BlockType'] == 'SELECTION_ELEMENT':
                            if word['SelectionStatus'] =='SELECTED':
                                text +=  'X '
        return text

    def generate_table_csv(self, table_result, blocks_map, table_index):
        rows = self.get_rows_columns_map(table_result, blocks_map)

        table_id = 'Table_' + str(table_index)

        csv = 'Table: {0}\n\n'.format(table_id)

        for row_index, cols in rows.items():

            for col_index, text in cols.items():
                csv += '{}'.format(text) + ","
            csv += '\n'

        csv += '\n\n\n'
        return csv

    def get_table_csv_results(self, response):
        blocks = response['Blocks']

        blocks_map = {}
        table_blocks = []
        for block in blocks:
            blocks_map[block['Id']] = block
            if block['BlockType'] == "TABLE":
                table_blocks.append(block)

        if len(table_blocks) <= 0:
            return "<b> NO Table FOUND </b>"

        csv = ''
        for index, table in enumerate(table_blocks):
            csv += self.generate_table_csv(table, blocks_map, index +1)
            csv += '\n\n'

        return csv

    def extract_info(self, access_key, secret_key, region):
        os.environ['AWS_ACCESS_KEY_ID'] = access_key
        os.environ['AWS_SECRET_ACCESS_KEY'] = secret_key
        os.environ['AWS_DEFAULT_REGION'] = region
        client = boto3.client('textract')
        self.responses = {}
        self.tables_info = {}
        for img_path in self.images_list:
            with open(img_path, 'rb') as file:
                tiff_image_bytes = file.read()
            response = client.analyze_document(
                Document={
                    'Bytes': tiff_image_bytes,
                },
                FeatureTypes=['TABLES']
            )
            self.responses[img_path] = response
            self.tables_info[img_path] = self.get_table_csv_results(response)

        return self.responses, self.tables_info

    def mark_tables(self, alpha = 0.3):
        self.only_tables = {}
        for key in tqdm(self.responses, desc = "FILES", total = len(self.responses)):
            self.only_tables[key] = []
            image = cv2.imread(key)
            original_height, original_width = image.shape[:-1]
            for obj in tqdm(self.responses[key]['Blocks'], total = len(self.responses[key]['Blocks']), desc = "BLOCKS", leave = False):
                if obj['BlockType'] == 'TABLE':
                    self.only_tables[key].append(obj)
                    width, height, left, top = obj['Geometry']['BoundingBox'].values()
                    width, height, left, top = int(width * original_width), int(height * original_height), int(left * original_width), int(top * original_height)

                    overlay = image.copy()
                    cv2.rectangle(overlay, (left, top), (left + width, top + height), (0, 255, 0), thickness = cv2.FILLED)
                    image = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)
            cv2.imwrite(key, image)
        return self.only_tables

# %%
class process_pdf_json():
    def __init__(self):
        pass

    def create_pdf_image(self, output_path, **kwargs):
        if not os.path.exists(output_path):
            os.makedirs(output_path)
        else:
            shutil.rmtree(output_path, ignore_errors=True)
            os.makedirs(output_path)
        self.images_list = convert_from_path(**kwargs, output_folder = output_path)
        for idx, file_path in enumerate(self.images_list):
            directory = os.path.dirname(file_path)
            filename = os.path.basename(file_path)

            if filename.endswith('.jpg'):
                original_number = filename.split('-')[-1].split('.')[0]
                new_filename = original_number + '.jpg'
                old_filepath = file_path
                new_filepath = os.path.join(directory, new_filename)
                os.rename(old_filepath, new_filepath)
                self.images_list[idx] = new_filepath

        return self.images_list

    def get_rows_columns_map(self, table_result, blocks_map):
        rows = {}
        for relationship in table_result['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    cell = blocks_map[child_id]
                    if cell['BlockType'] == 'CELL':
                        row_index = cell['RowIndex']
                        col_index = cell['ColumnIndex']
                        if row_index not in rows:
                            rows[row_index] = {}

                        rows[row_index][col_index] = self.get_text(cell, blocks_map)
        return rows

    def get_text(self, result, blocks_map):
        text = ''
        if 'Relationships' in result:
            for relationship in result['Relationships']:
                if relationship['Type'] == 'CHILD':
                    for child_id in relationship['Ids']:
                        word = blocks_map[child_id]
                        if word['BlockType'] == 'WORD':
                            text += word['Text'] + ' '
                        if word['BlockType'] == 'SELECTION_ELEMENT':
                            if word['SelectionStatus'] =='SELECTED':
                                text +=  'X '
        return text

    def generate_table_json(self, table_result, blocks_map, table_index):
        rows = self.get_rows_columns_map(table_result, blocks_map)

        table_id = 'Table_' + str(table_index)

        table_data = {'table_id': table_id, 'rows': []}

        for row_index, cols in rows.items():
            row_data = {'row_index': row_index, 'columns': []}
            for col_index, text in cols.items():
                column_data = {'column_index': col_index, 'text': text}
                row_data['columns'].append(column_data)
            table_data['rows'].append(row_data)

        return table_data

    def get_table_json_results(self, response):
        blocks = response['Blocks']

        blocks_map = {}
        table_blocks = []
        for block in blocks:
            blocks_map[block['Id']] = block
            if block['BlockType'] == "TABLE":
                table_blocks.append(block)

        if len(table_blocks) <= 0:
            return "<b> NO Table FOUND </b>"

        tables = []
        for index, table in enumerate(table_blocks):
            tables.append(self.generate_table_json(table, blocks_map, index +1))

        return tables

    def extract_info(self, access_key, secret_key, region, **kwargs):
        os.environ['AWS_ACCESS_KEY_ID'] = access_key
        os.environ['AWS_SECRET_ACCESS_KEY'] = secret_key
        os.environ['AWS_DEFAULT_REGION'] = region
        client = boto3.client('textract')
        self.responses = {}
        self.tables_info = {}
        images_list = convert_from_path(**kwargs)
        for i in range(len(images_list)):
            buf = io.BytesIO()
            images_list[i].save(buf, format='JPEG')
            byte_im = buf.getvalue()
            response = client.analyze_document(
                Document={
                    'Bytes': byte_im,
                },
                FeatureTypes=['TABLES']
            )
            self.responses[i] = response
            self.tables_info[i] = self.get_table_json_results(response)

        return self.responses, self.tables_info

    def mark_tables(self, alpha = 0.3):
        self.only_tables = {}
        for key in tqdm(self.responses, desc = "FILES", total = len(self.responses)):
            self.only_tables[key] = []
            image = cv2.imread(key)
            original_height, original_width = image.shape[:-1]
            for obj in tqdm(self.responses[key]['Blocks'], total = len(self.responses[key]['Blocks']), desc = "BLOCKS", leave = False):
                if obj['BlockType'] == 'TABLE':
                    self.only_tables[key].append(obj)
                    width, height, left, top = obj['Geometry']['BoundingBox'].values()
                    width, height, left, top = int(width * original_width), int(height * original_height), int(left * original_width), int(top * original_height)

                    overlay = image.copy()
                    cv2.rectangle(overlay, (left, top), (left + width, top + height), (0, 255, 0), thickness = cv2.FILLED)
                    image = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)
            cv2.imwrite(key, image)
        return self.only_tables

    def extract_text(self,filepath):
        text = {}
        doc = fitz.open(filepath)
        for i in tqdm(range(len(doc)), desc="pages"):
            page = doc.load_page(i)
            page_text = page.get_text()
            text[i] = page_text
        return text

# %%
#output_path = '/Users/sushilbagate/Downloads/EMAlpha/Notebooks/output_dir'
pdf_path = '/Users/sushilbagate/Downloads/Article_IV_2017.pdf'

pp = process_pdf_json()
#imgs = pp.create_pdf_image(output_path = output_path, pdf_path = pdf_path,
#                        fmt = "jpeg", first_page = 10, last_page = 12, paths_only = True)

## Add access_key, secret_key, region below

informationes, tables = pp.extract_info(pdf_path = pdf_path, access_key = "", secret_key = "", region = '')
#marked_tables = pp.mark_tables()

# %%
len(tables)
# Out:
# 58

# %%
tables[3]
# Out:
# [{'table_id': 'Table_1',
#   'rows': [{'row_index': 1,
#     'columns': [{'column_index': 1, 'text': 'Russian Federation: Selected '},
#      {'column_index': 2, 'text': 'Macroeconomic '},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': 'Indicators, '},
#      {'column_index': 5, 'text': '2014-18 '},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 2,
#     'columns': [{'column_index': 1, 'text': ''},
#      {'column_index': 2, 'text': '2014 '},
#      {'column_index': 3, 'text': '2015 '},
#      {'column_index': 4, 'text': '2016 '},
#      {'column_index': 5, 'text': '2017 '},
#      {'column_index': 6, 'text': '2018 '}]},
#    {'row_index': 3,
#     'columns': [{'column_index': 1, 'text': ''},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': 'Projections '},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 4,
#     'columns': [{'column_index': 1, 'text': 'Production and prices '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 5,
#     'columns': [{'column_index': 1, 'text': 'Real GDP '},
#      {'column_index': 2, 'text': '0.7 '},
#      {'column_index': 3, 'text': '-2.8 '},
#      {'column_index': 4, 'text': '-0.2 '},
#      {'column_index': 5, 'text': '1.4 '},
#      {'column_index': 6, 'text': '1.4 '}]},
#    {'row_index': 6,
#     'columns': [{'column_index': 1, 'text': 'Consumer prices '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 7,
#     'columns': [{'column_index': 1, 'text': 'Period average '},
#      {'column_index': 2, 'text': '7.8 '},
#      {'column_index': 3, 'text': '15.5 '},
#      {'column_index': 4, 'text': '7.0 '},
#      {'column_index': 5, 'text': '4.2 '},
#      {'column_index': 6, 'text': '4.0 '}]},
#    {'row_index': 8,
#     'columns': [{'column_index': 1, 'text': 'End of period '},
#      {'column_index': 2, 'text': '11.4 '},
#      {'column_index': 3, 'text': '12.9 '},
#      {'column_index': 4, 'text': '5.4 '},
#      {'column_index': 5, 'text': '4.0 '},
#      {'column_index': 6, 'text': '4.0 '}]},
#    {'row_index': 9,
#     'columns': [{'column_index': 1, 'text': 'GDP deflator '},
#      {'column_index': 2, 'text': '10.7 '},
#      {'column_index': 3, 'text': '8.2 '},
#      {'column_index': 4, 'text': '3.6 '},
#      {'column_index': 5, 'text': '5.7 '},
#      {'column_index': 6, 'text': '3.8 '}]},
#    {'row_index': 10,
#     'columns': [{'column_index': 1, 'text': 'Public sector¹ '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': '(Percent '},
#      {'column_index': 4, 'text': 'of GDP) '},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 11,
#     'columns': [{'column_index': 1, 'text': 'General government '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 12,
#     'columns': [{'column_index': 1,
#       'text': 'Net lending/borrowing (overall balance) '},
#      {'column_index': 2, 'text': '-1.1 '},
#      {'column_index': 3, 'text': '-3.4 '},
#      {'column_index': 4, 'text': '-3.7 '},
#      {'column_index': 5, 'text': '-1.9 '},
#      {'column_index': 6, 'text': '-1.2 '}]},
#    {'row_index': 13,
#     'columns': [{'column_index': 1, 'text': 'Revenue '},
#      {'column_index': 2, 'text': '33.8 '},
#      {'column_index': 3, 'text': '31.8 '},
#      {'column_index': 4, 'text': '32.8 '},
#      {'column_index': 5, 'text': '32.6 '},
#      {'column_index': 6, 'text': '31.9 '}]},
#    {'row_index': 14,
#     'columns': [{'column_index': 1, 'text': 'Expenditures '},
#      {'column_index': 2, 'text': '34.9 '},
#      {'column_index': 3, 'text': '35.2 '},
#      {'column_index': 4, 'text': '36.4 '},
#      {'column_index': 5, 'text': '34.5 '},
#      {'column_index': 6, 'text': '33.1 '}]},
#    {'row_index': 15,
#     'columns': [{'column_index': 1, 'text': 'Primary balance '},
#      {'column_index': 2, 'text': '-0.4 '},
#      {'column_index': 3, 'text': '-2.6 '},
#      {'column_index': 4, 'text': '-2.6 '},
#      {'column_index': 5, 'text': '-1.0 '},
#      {'column_index': 6, 'text': '-0.2 '}]},
#    {'row_index': 16,
#     'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#      {'column_index': 2, 'text': '-11,4 '},
#      {'column_index': 3, 'text': '-11.4 '},
#      {'column_index': 4, 'text': '-9.8 '},
#      {'column_index': 5, 'text': '-8.4 '},
#      {'column_index': 6, 'text': '-7.6 '}]},
#    {'row_index': 17,
#     'columns': [{'column_index': 1, 'text': 'Federal government '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 18,
#     'columns': [{'column_index': 1,
#       'text': 'Net lending/borrowing (overall balance) '},
#      {'column_index': 2, 'text': '-0.4 '},
#      {'column_index': 3, 'text': '-2.3 '},
#      {'column_index': 4, 'text': '-3.4 '},
#      {'column_index': 5, 'text': '-1.7 '},
#      {'column_index': 6, 'text': '-1.0 '}]},
#    {'row_index': 19,
#     'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#      {'column_index': 2, 'text': '-9.9 '},
#      {'column_index': 3, 'text': '-9.5 '},
#      {'column_index': 4, 'text': '-9.0 '},
#      {'column_index': 5, 'text': '-7.5 '},
#      {'column_index': 6, 'text': '-6.8 '}]},
#    {'row_index': 20,
#     'columns': [{'column_index': 1, 'text': ''},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': '(Annual '},
#      {'column_index': 4, 'text': 'percent '},
#      {'column_index': 5, 'text': 'change) '},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 21,
#     'columns': [{'column_index': 1, 'text': 'Base money '},
#      {'column_index': 2, 'text': '6.3 '},
#      {'column_index': 3, 'text': '-4.3 '},
#      {'column_index': 4, 'text': '3.8 '},
#      {'column_index': 5, 'text': '6.3 '},
#      {'column_index': 6, 'text': '6.4 '}]},
#    {'row_index': 22,
#     'columns': [{'column_index': 1, 'text': 'Ruble broad money '},
#      {'column_index': 2, 'text': '1.5 '},
#      {'column_index': 3, 'text': '11.3 '},
#      {'column_index': 4, 'text': '9.2 '},
#      {'column_index': 5, 'text': '9.4 '},
#      {'column_index': 6, 'text': '9.6 '}]},
#    {'row_index': 23,
#     'columns': [{'column_index': 1, 'text': 'External sector '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 24,
#     'columns': [{'column_index': 1, 'text': 'Export volumes '},
#      {'column_index': 2, 'text': '-0.2 '},
#      {'column_index': 3, 'text': '6.4 '},
#      {'column_index': 4, 'text': '0.9 '},
#      {'column_index': 5, 'text': '1.4 '},
#      {'column_index': 6, 'text': '3.4 '}]},
#    {'row_index': 25,
#     'columns': [{'column_index': 1, 'text': 'Oil '},
#      {'column_index': 2, 'text': '0.1 '},
#      {'column_index': 3, 'text': '7.0 '},
#      {'column_index': 4, 'text': '-8.5 '},
#      {'column_index': 5, 'text': '-2.1 '},
#      {'column_index': 6, 'text': '0.7 '}]},
#    {'row_index': 26,
#     'columns': [{'column_index': 1, 'text': 'Gas '},
#      {'column_index': 2, 'text': '-11.3 '},
#      {'column_index': 3, 'text': '6.5 '},
#      {'column_index': 4, 'text': '1.7 '},
#      {'column_index': 5, 'text': '-0.8 '},
#      {'column_index': 6, 'text': '0.1 '}]},
#    {'row_index': 27,
#     'columns': [{'column_index': 1, 'text': 'Non-energy '},
#      {'column_index': 2, 'text': '4.1 '},
#      {'column_index': 3, 'text': '-7.9 '},
#      {'column_index': 4, 'text': '11.2 '},
#      {'column_index': 5, 'text': '5.8 '},
#      {'column_index': 6, 'text': '6.9 '}]},
#    {'row_index': 28,
#     'columns': [{'column_index': 1, 'text': 'Import volumes '},
#      {'column_index': 2, 'text': '-8.0 '},
#      {'column_index': 3, 'text': '-25.2 '},
#      {'column_index': 4, 'text': '1.6 '},
#      {'column_index': 5, 'text': '2.8 '},
#      {'column_index': 6, 'text': '3.8 '}]},
#    {'row_index': 29,
#     'columns': [{'column_index': 1, 'text': ''},
#      {'column_index': 2, 'text': '(Billions of '},
#      {'column_index': 3, 'text': 'U.S. dollars: '},
#      {'column_index': 4, 'text': 'unless '},
#      {'column_index': 5, 'text': 'otherwise indicated) '},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 30,
#     'columns': [{'column_index': 1, 'text': 'External sector '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 31,
#     'columns': [{'column_index': 1, 'text': 'Total merchandise exports, fob '},
#      {'column_index': 2, 'text': '496.8 '},
#      {'column_index': 3, 'text': '341.5 '},
#      {'column_index': 4, 'text': '281.7 '},
#      {'column_index': 5, 'text': '330.4 '},
#      {'column_index': 6, 'text': '339.1 '}]},
#    {'row_index': 32,
#     'columns': [{'column_index': 1, 'text': 'Total merchandise imports, fob '},
#      {'column_index': 2, 'text': '-307.9 '},
#      {'column_index': 3, 'text': '-193.0 '},
#      {'column_index': 4, 'text': '-191,7 '},
#      {'column_index': 5, 'text': '-203,1 '},
#      {'column_index': 6, 'text': '-213,7 '}]},
#    {'row_index': 33,
#     'columns': [{'column_index': 1, 'text': 'External current account '},
#      {'column_index': 2, 'text': '57.5 '},
#      {'column_index': 3, 'text': '68.9 '},
#      {'column_index': 4, 'text': '25.0 '},
#      {'column_index': 5, 'text': '44.0 '},
#      {'column_index': 6, 'text': '48.9 '}]},
#    {'row_index': 34,
#     'columns': [{'column_index': 1,
#       'text': 'External current account (in percent of GDP) '},
#      {'column_index': 2, 'text': '2.8 '},
#      {'column_index': 3, 'text': '5.0 '},
#      {'column_index': 4, 'text': '1.9 '},
#      {'column_index': 5, 'text': '2,9 '},
#      {'column_index': 6, 'text': '3.2 '}]},
#    {'row_index': 35,
#     'columns': [{'column_index': 1, 'text': 'Gross international reserves '},
#      {'column_index': 2, 'text': '496.8 '},
#      {'column_index': 3, 'text': '341.5 '},
#      {'column_index': 4, 'text': '281.7 '},
#      {'column_index': 5, 'text': '330.4 '},
#      {'column_index': 6, 'text': '339.1 '}]},
#    {'row_index': 36,
#     'columns': [{'column_index': 1, 'text': 'Billions of U.S. dollars '},
#      {'column_index': 2, 'text': '385.5 '},
#      {'column_index': 3, 'text': '368.4 '},
#      {'column_index': 4, 'text': '377.7 '},
#      {'column_index': 5, 'text': '395.3 '},
#      {'column_index': 6, 'text': '412.6 '}]},
#    {'row_index': 37,
#     'columns': [{'column_index': 1, 'text': 'Months of imports '},
#      {'column_index': 2, 'text': '10.8 '},
#      {'column_index': 3, 'text': '15,7 '},
#      {'column_index': 4, 'text': '17.0 '},
#      {'column_index': 5, 'text': '16.8 '},
#      {'column_index': 6, 'text': '16.7 '}]},
#    {'row_index': 38,
#     'columns': [{'column_index': 1, 'text': 'Percent of short-term debt '},
#      {'column_index': 2, 'text': '302 '},
#      {'column_index': 3, 'text': '450 '},
#      {'column_index': 4, 'text': '419 '},
#      {'column_index': 5, 'text': '391 '},
#      {'column_index': 6, 'text': '417 '}]},
#    {'row_index': 39,
#     'columns': [{'column_index': 1, 'text': 'Memorandum items: '},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]},
#    {'row_index': 40,
#     'columns': [{'column_index': 1,
#       'text': 'Nominal GDP (billions of U.S.D) '},
#      {'column_index': 2, 'text': '2,064 '},
#      {'column_index': 3, 'text': '1,366 '},
#      {'column_index': 4, 'text': '1,283 '},
#      {'column_index': 5, 'text': '1,498 '},
#      {'column_index': 6, 'text': '1,551 '}]},
#    {'row_index': 41,
#     'columns': [{'column_index': 1,
#       'text': 'Exchange rate (rubles per U.S.D., period average) '},
#      {'column_index': 2, 'text': '38,4 '},
#      {'column_index': 3, 'text': '60,9 '},
#      {'column_index': 4, 'text': '... '},
#      {'column_index': 5, 'text': '... '},
#      {'column_index': 6, 'text': '... '}]},
#    {'row_index': 42,
#     'columns': [{'column_index': 1,
#       'text': 'World oil price (U.S.D. per barrel) '},
#      {'column_index': 2, 'text': '96.2 '},
#      {'column_index': 3, 'text': '50,8 '},
#      {'column_index': 4, 'text': '42.8 '},
#      {'column_index': 5, 'text': '51.9 '},
#      {'column_index': 6, 'text': '52.0 '}]},
#    {'row_index': 43,
#     'columns': [{'column_index': 1,
#       'text': 'Real effective exchange rate (average percent change) '},
#      {'column_index': 2, 'text': '-8.5 '},
#      {'column_index': 3, 'text': '-17.4 '},
#      {'column_index': 4, 'text': '... '},
#      {'column_index': 5, 'text': '... '},
#      {'column_index': 6, 'text': '... '}]},
#    {'row_index': 44,
#     'columns': [{'column_index': 1, 'text': ''},
#      {'column_index': 2, 'text': ''},
#      {'column_index': 3, 'text': ''},
#      {'column_index': 4, 'text': ''},
#      {'column_index': 5, 'text': ''},
#      {'column_index': 6, 'text': ''}]}]}]

# %%
## Tables per page
tables
# Out:
# {0: '<b> NO Table FOUND </b>',
#  1: '<b> NO Table FOUND </b>',
#  2: '<b> NO Table FOUND </b>',
#  3: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': 'Russian Federation: Selected '},
#       {'column_index': 2, 'text': 'Macroeconomic '},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': 'Indicators, '},
#       {'column_index': 5, 'text': '2014-18 '},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '2014 '},
#       {'column_index': 3, 'text': '2015 '},
#       {'column_index': 4, 'text': '2016 '},
#       {'column_index': 5, 'text': '2017 '},
#       {'column_index': 6, 'text': '2018 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': 'Projections '},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': 'Production and prices '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Real GDP '},
#       {'column_index': 2, 'text': '0.7 '},
#       {'column_index': 3, 'text': '-2.8 '},
#       {'column_index': 4, 'text': '-0.2 '},
#       {'column_index': 5, 'text': '1.4 '},
#       {'column_index': 6, 'text': '1.4 '}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1, 'text': 'Consumer prices '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 7,
#      'columns': [{'column_index': 1, 'text': 'Period average '},
#       {'column_index': 2, 'text': '7.8 '},
#       {'column_index': 3, 'text': '15.5 '},
#       {'column_index': 4, 'text': '7.0 '},
#       {'column_index': 5, 'text': '4.2 '},
#       {'column_index': 6, 'text': '4.0 '}]},
#     {'row_index': 8,
#      'columns': [{'column_index': 1, 'text': 'End of period '},
#       {'column_index': 2, 'text': '11.4 '},
#       {'column_index': 3, 'text': '12.9 '},
#       {'column_index': 4, 'text': '5.4 '},
#       {'column_index': 5, 'text': '4.0 '},
#       {'column_index': 6, 'text': '4.0 '}]},
#     {'row_index': 9,
#      'columns': [{'column_index': 1, 'text': 'GDP deflator '},
#       {'column_index': 2, 'text': '10.7 '},
#       {'column_index': 3, 'text': '8.2 '},
#       {'column_index': 4, 'text': '3.6 '},
#       {'column_index': 5, 'text': '5.7 '},
#       {'column_index': 6, 'text': '3.8 '}]},
#     {'row_index': 10,
#      'columns': [{'column_index': 1, 'text': 'Public sector¹ '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': '(Percent '},
#       {'column_index': 4, 'text': 'of GDP) '},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 11,
#      'columns': [{'column_index': 1, 'text': 'General government '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 12,
#      'columns': [{'column_index': 1,
#        'text': 'Net lending/borrowing (overall balance) '},
#       {'column_index': 2, 'text': '-1.1 '},
#       {'column_index': 3, 'text': '-3.4 '},
#       {'column_index': 4, 'text': '-3.7 '},
#       {'column_index': 5, 'text': '-1.9 '},
#       {'column_index': 6, 'text': '-1.2 '}]},
#     {'row_index': 13,
#      'columns': [{'column_index': 1, 'text': 'Revenue '},
#       {'column_index': 2, 'text': '33.8 '},
#       {'column_index': 3, 'text': '31.8 '},
#       {'column_index': 4, 'text': '32.8 '},
#       {'column_index': 5, 'text': '32.6 '},
#       {'column_index': 6, 'text': '31.9 '}]},
#     {'row_index': 14,
#      'columns': [{'column_index': 1, 'text': 'Expenditures '},
#       {'column_index': 2, 'text': '34.9 '},
#       {'column_index': 3, 'text': '35.2 '},
#       {'column_index': 4, 'text': '36.4 '},
#       {'column_index': 5, 'text': '34.5 '},
#       {'column_index': 6, 'text': '33.1 '}]},
#     {'row_index': 15,
#      'columns': [{'column_index': 1, 'text': 'Primary balance '},
#       {'column_index': 2, 'text': '-0.4 '},
#       {'column_index': 3, 'text': '-2.6 '},
#       {'column_index': 4, 'text': '-2.6 '},
#       {'column_index': 5, 'text': '-1.0 '},
#       {'column_index': 6, 'text': '-0.2 '}]},
#     {'row_index': 16,
#      'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#       {'column_index': 2, 'text': '-11,4 '},
#       {'column_index': 3, 'text': '-11.4 '},
#       {'column_index': 4, 'text': '-9.8 '},
#       {'column_index': 5, 'text': '-8.4 '},
#       {'column_index': 6, 'text': '-7.6 '}]},
#     {'row_index': 17,
#      'columns': [{'column_index': 1, 'text': 'Federal government '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 18,
#      'columns': [{'column_index': 1,
#        'text': 'Net lending/borrowing (overall balance) '},
#       {'column_index': 2, 'text': '-0.4 '},
#       {'column_index': 3, 'text': '-2.3 '},
#       {'column_index': 4, 'text': '-3.4 '},
#       {'column_index': 5, 'text': '-1.7 '},
#       {'column_index': 6, 'text': '-1.0 '}]},
#     {'row_index': 19,
#      'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#       {'column_index': 2, 'text': '-9.9 '},
#       {'column_index': 3, 'text': '-9.5 '},
#       {'column_index': 4, 'text': '-9.0 '},
#       {'column_index': 5, 'text': '-7.5 '},
#       {'column_index': 6, 'text': '-6.8 '}]},
#     {'row_index': 20,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': '(Annual '},
#       {'column_index': 4, 'text': 'percent '},
#       {'column_index': 5, 'text': 'change) '},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 21,
#      'columns': [{'column_index': 1, 'text': 'Base money '},
#       {'column_index': 2, 'text': '6.3 '},
#       {'column_index': 3, 'text': '-4.3 '},
#       {'column_index': 4, 'text': '3.8 '},
#       {'column_index': 5, 'text': '6.3 '},
#       {'column_index': 6, 'text': '6.4 '}]},
#     {'row_index': 22,
#      'columns': [{'column_index': 1, 'text': 'Ruble broad money '},
#       {'column_index': 2, 'text': '1.5 '},
#       {'column_index': 3, 'text': '11.3 '},
#       {'column_index': 4, 'text': '9.2 '},
#       {'column_index': 5, 'text': '9.4 '},
#       {'column_index': 6, 'text': '9.6 '}]},
#     {'row_index': 23,
#      'columns': [{'column_index': 1, 'text': 'External sector '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 24,
#      'columns': [{'column_index': 1, 'text': 'Export volumes '},
#       {'column_index': 2, 'text': '-0.2 '},
#       {'column_index': 3, 'text': '6.4 '},
#       {'column_index': 4, 'text': '0.9 '},
#       {'column_index': 5, 'text': '1.4 '},
#       {'column_index': 6, 'text': '3.4 '}]},
#     {'row_index': 25,
#      'columns': [{'column_index': 1, 'text': 'Oil '},
#       {'column_index': 2, 'text': '0.1 '},
#       {'column_index': 3, 'text': '7.0 '},
#       {'column_index': 4, 'text': '-8.5 '},
#       {'column_index': 5, 'text': '-2.1 '},
#       {'column_index': 6, 'text': '0.7 '}]},
#     {'row_index': 26,
#      'columns': [{'column_index': 1, 'text': 'Gas '},
#       {'column_index': 2, 'text': '-11.3 '},
#       {'column_index': 3, 'text': '6.5 '},
#       {'column_index': 4, 'text': '1.7 '},
#       {'column_index': 5, 'text': '-0.8 '},
#       {'column_index': 6, 'text': '0.1 '}]},
#     {'row_index': 27,
#      'columns': [{'column_index': 1, 'text': 'Non-energy '},
#       {'column_index': 2, 'text': '4.1 '},
#       {'column_index': 3, 'text': '-7.9 '},
#       {'column_index': 4, 'text': '11.2 '},
#       {'column_index': 5, 'text': '5.8 '},
#       {'column_index': 6, 'text': '6.9 '}]},
#     {'row_index': 28,
#      'columns': [{'column_index': 1, 'text': 'Import volumes '},
#       {'column_index': 2, 'text': '-8.0 '},
#       {'column_index': 3, 'text': '-25.2 '},
#       {'column_index': 4, 'text': '1.6 '},
#       {'column_index': 5, 'text': '2.8 '},
#       {'column_index': 6, 'text': '3.8 '}]},
#     {'row_index': 29,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '(Billions of '},
#       {'column_index': 3, 'text': 'U.S. dollars: '},
#       {'column_index': 4, 'text': 'unless '},
#       {'column_index': 5, 'text': 'otherwise indicated) '},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 30,
#      'columns': [{'column_index': 1, 'text': 'External sector '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 31,
#      'columns': [{'column_index': 1,
#        'text': 'Total merchandise exports, fob '},
#       {'column_index': 2, 'text': '496.8 '},
#       {'column_index': 3, 'text': '341.5 '},
#       {'column_index': 4, 'text': '281.7 '},
#       {'column_index': 5, 'text': '330.4 '},
#       {'column_index': 6, 'text': '339.1 '}]},
#     {'row_index': 32,
#      'columns': [{'column_index': 1,
#        'text': 'Total merchandise imports, fob '},
#       {'column_index': 2, 'text': '-307.9 '},
#       {'column_index': 3, 'text': '-193.0 '},
#       {'column_index': 4, 'text': '-191,7 '},
#       {'column_index': 5, 'text': '-203,1 '},
#       {'column_index': 6, 'text': '-213,7 '}]},
#     {'row_index': 33,
#      'columns': [{'column_index': 1, 'text': 'External current account '},
#       {'column_index': 2, 'text': '57.5 '},
#       {'column_index': 3, 'text': '68.9 '},
#       {'column_index': 4, 'text': '25.0 '},
#       {'column_index': 5, 'text': '44.0 '},
#       {'column_index': 6, 'text': '48.9 '}]},
#     {'row_index': 34,
#      'columns': [{'column_index': 1,
#        'text': 'External current account (in percent of GDP) '},
#       {'column_index': 2, 'text': '2.8 '},
#       {'column_index': 3, 'text': '5.0 '},
#       {'column_index': 4, 'text': '1.9 '},
#       {'column_index': 5, 'text': '2,9 '},
#       {'column_index': 6, 'text': '3.2 '}]},
#     {'row_index': 35,
#      'columns': [{'column_index': 1, 'text': 'Gross international reserves '},
#       {'column_index': 2, 'text': '496.8 '},
#       {'column_index': 3, 'text': '341.5 '},
#       {'column_index': 4, 'text': '281.7 '},
#       {'column_index': 5, 'text': '330.4 '},
#       {'column_index': 6, 'text': '339.1 '}]},
#     {'row_index': 36,
#      'columns': [{'column_index': 1, 'text': 'Billions of U.S. dollars '},
#       {'column_index': 2, 'text': '385.5 '},
#       {'column_index': 3, 'text': '368.4 '},
#       {'column_index': 4, 'text': '377.7 '},
#       {'column_index': 5, 'text': '395.3 '},
#       {'column_index': 6, 'text': '412.6 '}]},
#     {'row_index': 37,
#      'columns': [{'column_index': 1, 'text': 'Months of imports '},
#       {'column_index': 2, 'text': '10.8 '},
#       {'column_index': 3, 'text': '15,7 '},
#       {'column_index': 4, 'text': '17.0 '},
#       {'column_index': 5, 'text': '16.8 '},
#       {'column_index': 6, 'text': '16.7 '}]},
#     {'row_index': 38,
#      'columns': [{'column_index': 1, 'text': 'Percent of short-term debt '},
#       {'column_index': 2, 'text': '302 '},
#       {'column_index': 3, 'text': '450 '},
#       {'column_index': 4, 'text': '419 '},
#       {'column_index': 5, 'text': '391 '},
#       {'column_index': 6, 'text': '417 '}]},
#     {'row_index': 39,
#      'columns': [{'column_index': 1, 'text': 'Memorandum items: '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 40,
#      'columns': [{'column_index': 1,
#        'text': 'Nominal GDP (billions of U.S.D) '},
#       {'column_index': 2, 'text': '2,064 '},
#       {'column_index': 3, 'text': '1,366 '},
#       {'column_index': 4, 'text': '1,283 '},
#       {'column_index': 5, 'text': '1,498 '},
#       {'column_index': 6, 'text': '1,551 '}]},
#     {'row_index': 41,
#      'columns': [{'column_index': 1,
#        'text': 'Exchange rate (rubles per U.S.D., period average) '},
#       {'column_index': 2, 'text': '38,4 '},
#       {'column_index': 3, 'text': '60,9 '},
#       {'column_index': 4, 'text': '... '},
#       {'column_index': 5, 'text': '... '},
#       {'column_index': 6, 'text': '... '}]},
#     {'row_index': 42,
#      'columns': [{'column_index': 1,
#        'text': 'World oil price (U.S.D. per barrel) '},
#       {'column_index': 2, 'text': '96.2 '},
#       {'column_index': 3, 'text': '50,8 '},
#       {'column_index': 4, 'text': '42.8 '},
#       {'column_index': 5, 'text': '51.9 '},
#       {'column_index': 6, 'text': '52.0 '}]},
#     {'row_index': 43,
#      'columns': [{'column_index': 1,
#        'text': 'Real effective exchange rate (average percent change) '},
#       {'column_index': 2, 'text': '-8.5 '},
#       {'column_index': 3, 'text': '-17.4 '},
#       {'column_index': 4, 'text': '... '},
#       {'column_index': 5, 'text': '... '},
#       {'column_index': 6, 'text': '... '}]},
#     {'row_index': 44,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]}]}],
#  4: '<b> NO Table FOUND </b>',
#  5: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1,
#        'text': "1. Evaluating Russia's New Proposed Fiscal Rule "},
#       {'column_index': 2, 'text': '10 '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1,
#        'text': '2. Fiscal Federalism and Regional Economic Performance '},
#       {'column_index': 2, 'text': '11 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1,
#        'text': "3. Russia's Core Inflation Philips Curve: A Time-Varying Approach "},
#       {'column_index': 2, 'text': '13 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': '4. Footprint of the State '},
#       {'column_index': 2, 'text': '16 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1,
#        'text': '5. The Muted Response of Non-Commodity Exports to REER Depreciation '},
#       {'column_index': 2, 'text': '18 '}]}]},
#   {'table_id': 'Table_2',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1,
#        'text': '1. Real Sector Developments, 1997-2017 '},
#       {'column_index': 2, 'text': '23 '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1,
#        'text': '2. External Sector Developments, 1997-2017 '},
#       {'column_index': 2, 'text': '24 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': '3. Fiscal Policy, 2000-2022 '},
#       {'column_index': 2, 'text': '25 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1,
#        'text': '4. Monetary Policy and Inflation, 2013-2017 '},
#       {'column_index': 2, 'text': '26 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1,
#        'text': '5. Banking Sector Developments, 2008-2017 '},
#       {'column_index': 2, 'text': '27 '}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1,
#        'text': '6. Macro-Financial Developments, 2008-2017 '},
#       {'column_index': 2, 'text': '28 '}]}]}],
#  6: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1,
#        'text': '1. Selected Macroeconomic Indicators, 2014-22 '},
#       {'column_index': 2, 'text': '29 '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1,
#        'text': '2. Balance of Payments, 2014-22 '},
#       {'column_index': 2, 'text': '30 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1,
#        'text': '3. External Financing Requirements and Sources, 2014-2022 '},
#       {'column_index': 2, 'text': '31 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': '4. Fiscal Operations, 2014-22 '},
#       {'column_index': 2, 'text': '32 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': '5. Monetary Accounts, 2014-22 '},
#       {'column_index': 2, 'text': '33 '}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1,
#        'text': '6. Medium-Term Framework, 2014-22 '},
#       {'column_index': 2, 'text': '34 '}]},
#     {'row_index': 7,
#      'columns': [{'column_index': 1,
#        'text': '7. Financial Soundness Indicators, 2013-2017 '},
#       {'column_index': 2, 'text': '35 '}]},
#     {'row_index': 8,
#      'columns': [{'column_index': 1,
#        'text': '8. Public Sector Debt Sustainability Analysis (DSA) - -Baseline Scenario '},
#       {'column_index': 2, 'text': '36 '}]},
#     {'row_index': 9,
#      'columns': [{'column_index': 1,
#        'text': '9. Public DSA - Composition of Public Debt and Alternative Scenarios '},
#       {'column_index': 2, 'text': '37 '}]},
#     {'row_index': 10,
#      'columns': [{'column_index': 1, 'text': '10. Public DSA - Stress Tests '},
#       {'column_index': 2, 'text': '38 '}]},
#     {'row_index': 11,
#      'columns': [{'column_index': 1,
#        'text': '11. External Debt Sustainability Framework, 2012-2022 '},
#       {'column_index': 2, 'text': '39 '}]},
#     {'row_index': 12,
#      'columns': [{'column_index': 1,
#        'text': '12. External Debt Sustainability: Bound Tests '},
#       {'column_index': 2, 'text': '40 '}]}]},
#   {'table_id': 'Table_2',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1,
#        'text': 'I. Implementation of Past IMF Recommendations '},
#       {'column_index': 2, 'text': '41 '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1,
#        'text': 'II. External Sector Assessment '},
#       {'column_index': 2, 'text': '43 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1,
#        'text': 'III. Risk Assessment Matrix (RAM) '},
#       {'column_index': 2, 'text': '45 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1,
#        'text': 'IV. Implementation of FSAP Recommendations '},
#       {'column_index': 2, 'text': '46 '}]}]}],
#  7: '<b> NO Table FOUND </b>',
#  8: '<b> NO Table FOUND </b>',
#  9: '<b> NO Table FOUND </b>',
#  10: '<b> NO Table FOUND </b>',
#  11: '<b> NO Table FOUND </b>',
#  12: '<b> NO Table FOUND </b>',
#  13: '<b> NO Table FOUND </b>',
#  14: '<b> NO Table FOUND </b>',
#  15: '<b> NO Table FOUND </b>',
#  16: '<b> NO Table FOUND </b>',
#  17: '<b> NO Table FOUND </b>',
#  18: '<b> NO Table FOUND </b>',
#  19: '<b> NO Table FOUND </b>',
#  20: '<b> NO Table FOUND </b>',
#  21: '<b> NO Table FOUND </b>',
#  22: '<b> NO Table FOUND </b>',
#  23: '<b> NO Table FOUND </b>',
#  24: '<b> NO Table FOUND </b>',
#  25: '<b> NO Table FOUND </b>',
#  26: '<b> NO Table FOUND </b>',
#  27: '<b> NO Table FOUND </b>',
#  28: '<b> NO Table FOUND </b>',
#  29: '<b> NO Table FOUND </b>',
#  30: '<b> NO Table FOUND </b>',
#  31: '<b> NO Table FOUND </b>',
#  32: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '2014 '},
#       {'column_index': 3, 'text': '2015 '},
#       {'column_index': 4, 'text': '2016 '},
#       {'column_index': 5, 'text': '2017 '},
#       {'column_index': 6, 'text': '2018 '},
#       {'column_index': 7, 'text': '2019 '},
#       {'column_index': 8, 'text': '2020 '},
#       {'column_index': 9, 'text': '2021 '},
#       {'column_index': 10, 'text': '2022 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': 'Est. '},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': 'Projection '},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': '(Annual '},
#       {'column_index': 6, 'text': 'percent change) '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Production and prices '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1, 'text': 'Real GDP '},
#       {'column_index': 2, 'text': '0.7 '},
#       {'column_index': 3, 'text': '-2.8 '},
#       {'column_index': 4, 'text': '-0.2 '},
#       {'column_index': 5, 'text': '1.4 '},
#       {'column_index': 6, 'text': '1.4 '},
#       {'column_index': 7, 'text': '1.5 '},
#       {'column_index': 8, 'text': '1.5 '},
#       {'column_index': 9, 'text': '1.5 '},
#       {'column_index': 10, 'text': '1.5 '}]},
#     {'row_index': 7,
#      'columns': [{'column_index': 1, 'text': 'Real domestic demand '},
#       {'column_index': 2, 'text': '-0.3 '},
#       {'column_index': 3, 'text': '-9.3 '},
#       {'column_index': 4, 'text': '-2.3 '},
#       {'column_index': 5, 'text': '1.0 '},
#       {'column_index': 6, 'text': '1.0 '},
#       {'column_index': 7, 'text': '1.1 '},
#       {'column_index': 8, 'text': '1.2 '},
#       {'column_index': 9, 'text': '1.2 '},
#       {'column_index': 10, 'text': '1.2 '}]},
#     {'row_index': 8,
#      'columns': [{'column_index': 1, 'text': 'Consumption '},
#       {'column_index': 2, 'text': '0,9 '},
#       {'column_index': 3, 'text': '-8.0 '},
#       {'column_index': 4, 'text': '-3.5 '},
#       {'column_index': 5, 'text': '0.6 '},
#       {'column_index': 6, 'text': '1.0 '},
#       {'column_index': 7, 'text': '1.1 '},
#       {'column_index': 8, 'text': '1.3 '},
#       {'column_index': 9, 'text': '1.3 '},
#       {'column_index': 10, 'text': '1.3 '}]},
#     {'row_index': 9,
#      'columns': [{'column_index': 1, 'text': 'Investment '},
#       {'column_index': 2, 'text': '-4.4 '},
#       {'column_index': 3, 'text': '-13.4 '},
#       {'column_index': 4, 'text': '1.5 '},
#       {'column_index': 5, 'text': '2.5 '},
#       {'column_index': 6, 'text': '1.0 '},
#       {'column_index': 7, 'text': '1.0 '},
#       {'column_index': 8, 'text': '1.0 '},
#       {'column_index': 9, 'text': '1.0 '},
#       {'column_index': 10, 'text': '1.0 '}]},
#     {'row_index': 10,
#      'columns': [{'column_index': 1, 'text': 'Consumer prices '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 11,
#      'columns': [{'column_index': 1, 'text': 'Period average '},
#       {'column_index': 2, 'text': '7.8 '},
#       {'column_index': 3, 'text': '15.5 '},
#       {'column_index': 4, 'text': '7.0 '},
#       {'column_index': 5, 'text': '4.2 '},
#       {'column_index': 6, 'text': '4.0 '},
#       {'column_index': 7, 'text': '4.0 '},
#       {'column_index': 8, 'text': '4.0 '},
#       {'column_index': 9, 'text': '4.0 '},
#       {'column_index': 10, 'text': '4.0 '}]},
#     {'row_index': 12,
#      'columns': [{'column_index': 1, 'text': 'End of period '},
#       {'column_index': 2, 'text': '11.4 '},
#       {'column_index': 3, 'text': '12.9 '},
#       {'column_index': 4, 'text': '5.4 '},
#       {'column_index': 5, 'text': '4.0 '},
#       {'column_index': 6, 'text': '4.0 '},
#       {'column_index': 7, 'text': '4.0 '},
#       {'column_index': 8, 'text': '4.0 '},
#       {'column_index': 9, 'text': '4.0 '},
#       {'column_index': 10, 'text': '4.0 '}]},
#     {'row_index': 13,
#      'columns': [{'column_index': 1, 'text': 'GDP deflator '},
#       {'column_index': 2, 'text': '10.7 '},
#       {'column_index': 3, 'text': '8.2 '},
#       {'column_index': 4, 'text': '3.6 '},
#       {'column_index': 5, 'text': '5.7 '},
#       {'column_index': 6, 'text': '3.8 '},
#       {'column_index': 7, 'text': '4.0 '},
#       {'column_index': 8, 'text': '3.9 '},
#       {'column_index': 9, 'text': '4.0 '},
#       {'column_index': 10, 'text': '3,9 '}]},
#     {'row_index': 14,
#      'columns': [{'column_index': 1, 'text': 'Unemployment rate '},
#       {'column_index': 2, 'text': '5.2 '},
#       {'column_index': 3, 'text': '5.6 '},
#       {'column_index': 4, 'text': '5.5 '},
#       {'column_index': 5, 'text': '5.5 '},
#       {'column_index': 6, 'text': '5.5 '},
#       {'column_index': 7, 'text': '5.5 '},
#       {'column_index': 8, 'text': '5.5 '},
#       {'column_index': 9, 'text': '5.5 '},
#       {'column_index': 10, 'text': '5.5 '}]},
#     {'row_index': 15,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': '(Percent '},
#       {'column_index': 6, 'text': 'of GDP) '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 16,
#      'columns': [{'column_index': 1, 'text': 'Public sector 1/ '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 17,
#      'columns': [{'column_index': 1, 'text': 'General government '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 18,
#      'columns': [{'column_index': 1,
#        'text': 'Net lending/borrowing (overall balance) '},
#       {'column_index': 2, 'text': '-1.1 '},
#       {'column_index': 3, 'text': '-3,4 '},
#       {'column_index': 4, 'text': '-3,7 '},
#       {'column_index': 5, 'text': '-1.9 '},
#       {'column_index': 6, 'text': '-1.2 '},
#       {'column_index': 7, 'text': '-0.7 '},
#       {'column_index': 8, 'text': '0.1 '},
#       {'column_index': 9, 'text': '0.5 '},
#       {'column_index': 10, 'text': '0,6 '}]},
#     {'row_index': 19,
#      'columns': [{'column_index': 1, 'text': 'Revenue '},
#       {'column_index': 2, 'text': '33.8 '},
#       {'column_index': 3, 'text': '31.8 '},
#       {'column_index': 4, 'text': '32.8 '},
#       {'column_index': 5, 'text': '32.6 '},
#       {'column_index': 6, 'text': '31.9 '},
#       {'column_index': 7, 'text': '31.7 '},
#       {'column_index': 8, 'text': '31.9 '},
#       {'column_index': 9, 'text': '32.2 '},
#       {'column_index': 10, 'text': '32.3 '}]},
#     {'row_index': 20,
#      'columns': [{'column_index': 1, 'text': 'Expenditures '},
#       {'column_index': 2, 'text': '34.9 '},
#       {'column_index': 3, 'text': '35.2 '},
#       {'column_index': 4, 'text': '36.4 '},
#       {'column_index': 5, 'text': '34.5 '},
#       {'column_index': 6, 'text': '33.1 '},
#       {'column_index': 7, 'text': '32.3 '},
#       {'column_index': 8, 'text': '31.8 '},
#       {'column_index': 9, 'text': '31.7 '},
#       {'column_index': 10, 'text': '31,7 '}]},
#     {'row_index': 21,
#      'columns': [{'column_index': 1, 'text': 'Primary balance '},
#       {'column_index': 2, 'text': '-0.4 '},
#       {'column_index': 3, 'text': '-2.6 '},
#       {'column_index': 4, 'text': '-2.6 '},
#       {'column_index': 5, 'text': '-1.0 '},
#       {'column_index': 6, 'text': '-0.2 '},
#       {'column_index': 7, 'text': '0.3 '},
#       {'column_index': 8, 'text': '1.1 '},
#       {'column_index': 9, 'text': '1.5 '},
#       {'column_index': 10, 'text': '1.7 '}]},
#     {'row_index': 22,
#      'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#       {'column_index': 2, 'text': '-11.4 '},
#       {'column_index': 3, 'text': '-11.4 '},
#       {'column_index': 4, 'text': '-9.8 '},
#       {'column_index': 5, 'text': '-8.4 '},
#       {'column_index': 6, 'text': '-7.6 '},
#       {'column_index': 7, 'text': '-6.9 '},
#       {'column_index': 8, 'text': '-6.0 '},
#       {'column_index': 9, 'text': '-5.5 '},
#       {'column_index': 10, 'text': '-5,4 '}]},
#     {'row_index': 23,
#      'columns': [{'column_index': 1,
#        'text': 'Nonoil primary structural balance '},
#       {'column_index': 2, 'text': '-10.2 '},
#       {'column_index': 3, 'text': '-10.5 '},
#       {'column_index': 4, 'text': '-8.9 '},
#       {'column_index': 5, 'text': '-8.1 '},
#       {'column_index': 6, 'text': '-7.4 '},
#       {'column_index': 7, 'text': '-6.6 '},
#       {'column_index': 8, 'text': '-5.7 '},
#       {'column_index': 9, 'text': '-5.2 '},
#       {'column_index': 10, 'text': '-5.1 '}]},
#     {'row_index': 24,
#      'columns': [{'column_index': 1, 'text': 'Federal government '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 25,
#      'columns': [{'column_index': 1,
#        'text': 'Net lending/borrowing (overall balance) '},
#       {'column_index': 2, 'text': '-0.4 '},
#       {'column_index': 3, 'text': '-2.3 '},
#       {'column_index': 4, 'text': '-3,4 '},
#       {'column_index': 5, 'text': '-1.7 '},
#       {'column_index': 6, 'text': '-1.0 '},
#       {'column_index': 7, 'text': '-0.3 '},
#       {'column_index': 8, 'text': '0.0 '},
#       {'column_index': 9, 'text': '0.0 '},
#       {'column_index': 10, 'text': '0.0 '}]},
#     {'row_index': 26,
#      'columns': [{'column_index': 1, 'text': 'Nonoil balance '},
#       {'column_index': 2, 'text': '-9.9 '},
#       {'column_index': 3, 'text': '-9.5 '},
#       {'column_index': 4, 'text': '-9.0 '},
#       {'column_index': 5, 'text': '-7.5 '},
#       {'column_index': 6, 'text': '-6.8 '},
#       {'column_index': 7, 'text': '-5.9 '},
#       {'column_index': 8, 'text': '-5.5 '},
#       {'column_index': 9, 'text': '-5.4 '},
#       {'column_index': 10, 'text': '-5,4 '}]},
#     {'row_index': 27,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': '(Annual '},
#       {'column_index': 6, 'text': 'percent change) '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 28,
#      'columns': [{'column_index': 1, 'text': 'Money '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 29,
#      'columns': [{'column_index': 1, 'text': 'Base money '},
#       {'column_index': 2, 'text': '6.3 '},
#       {'column_index': 3, 'text': '-4.3 '},
#       {'column_index': 4, 'text': '3.8 '},
#       {'column_index': 5, 'text': '6.3 '},
#       {'column_index': 6, 'text': '6.4 '},
#       {'column_index': 7, 'text': '6.4 '},
#       {'column_index': 8, 'text': '6.4 '},
#       {'column_index': 9, 'text': '6.4 '},
#       {'column_index': 10, 'text': '6.4 '}]},
#     {'row_index': 30,
#      'columns': [{'column_index': 1, 'text': 'Ruble broad money '},
#       {'column_index': 2, 'text': '1.5 '},
#       {'column_index': 3, 'text': '11.3 '},
#       {'column_index': 4, 'text': '9.2 '},
#       {'column_index': 5, 'text': '9.4 '},
#       {'column_index': 6, 'text': '9.6 '},
#       {'column_index': 7, 'text': '9.6 '},
#       {'column_index': 8, 'text': '9.6 '},
#       {'column_index': 9, 'text': '9.6 '},
#       {'column_index': 10, 'text': '9.6 '}]},
#     {'row_index': 31,
#      'columns': [{'column_index': 1, 'text': 'Credit to the economy '},
#       {'column_index': 2, 'text': '29.6 '},
#       {'column_index': 3, 'text': '8,4 '},
#       {'column_index': 4, 'text': '-1.6 '},
#       {'column_index': 5, 'text': '5.4 '},
#       {'column_index': 6, 'text': '7.8 '},
#       {'column_index': 7, 'text': '9.8 '},
#       {'column_index': 8, 'text': '9.8 '},
#       {'column_index': 9, 'text': '9.8 '},
#       {'column_index': 10, 'text': '9.8 '}]},
#     {'row_index': 32,
#      'columns': [{'column_index': 1, 'text': 'External sector '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 33,
#      'columns': [{'column_index': 1, 'text': 'Export volumes '},
#       {'column_index': 2, 'text': '-0.2 '},
#       {'column_index': 3, 'text': '6.4 '},
#       {'column_index': 4, 'text': '0,9 '},
#       {'column_index': 5, 'text': '1.4 '},
#       {'column_index': 6, 'text': '3.4 '},
#       {'column_index': 7, 'text': '3.6 '},
#       {'column_index': 8, 'text': '3.6 '},
#       {'column_index': 9, 'text': '3.6 '},
#       {'column_index': 10, 'text': '4.3 '}]},
#     {'row_index': 34,
#      'columns': [{'column_index': 1, 'text': 'Oil '},
#       {'column_index': 2, 'text': '0.1 '},
#       {'column_index': 3, 'text': '7.0 '},
#       {'column_index': 4, 'text': '-8.5 '},
#       {'column_index': 5, 'text': '-2.1 '},
#       {'column_index': 6, 'text': '0.7 '},
#       {'column_index': 7, 'text': '0.2 '},
#       {'column_index': 8, 'text': '0.5 '},
#       {'column_index': 9, 'text': '0.5 '},
#       {'column_index': 10, 'text': '2.1 '}]},
#     {'row_index': 35,
#      'columns': [{'column_index': 1, 'text': 'Gas '},
#       {'column_index': 2, 'text': '-11.3 '},
#       {'column_index': 3, 'text': '6.5 '},
#       {'column_index': 4, 'text': '1.7 '},
#       {'column_index': 5, 'text': '-0.8 '},
#       {'column_index': 6, 'text': '0.1 '},
#       {'column_index': 7, 'text': '0.0 '},
#       {'column_index': 8, 'text': '0.0 '},
#       {'column_index': 9, 'text': '0.0 '},
#       {'column_index': 10, 'text': '2.0 '}]},
#     {'row_index': 36,
#      'columns': [{'column_index': 1, 'text': 'Non-energy '},
#       {'column_index': 2, 'text': '4.1 '},
#       {'column_index': 3, 'text': '-7,9 '},
#       {'column_index': 4, 'text': '11.2 '},
#       {'column_index': 5, 'text': '5.8 '},
#       {'column_index': 6, 'text': '6.9 '},
#       {'column_index': 7, 'text': '7.6 '},
#       {'column_index': 8, 'text': '7.0 '},
#       {'column_index': 9, 'text': '6.7 '},
#       {'column_index': 10, 'text': '6.4 '}]},
#     {'row_index': 37,
#      'columns': [{'column_index': 1, 'text': 'Import volumes '},
#       {'column_index': 2, 'text': '-8.0 '},
#       {'column_index': 3, 'text': '-25,2 '},
#       {'column_index': 4, 'text': '1.6 '},
#       {'column_index': 5, 'text': '2.8 '},
#       {'column_index': 6, 'text': '3.8 '},
#       {'column_index': 7, 'text': '2.4 '},
#       {'column_index': 8, 'text': '2.4 '},
#       {'column_index': 9, 'text': '4.4 '},
#       {'column_index': 10, 'text': '5.6 '}]},
#     {'row_index': 38,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': '(Billions '},
#       {'column_index': 5, 'text': 'of U.S. dollars; '},
#       {'column_index': 6, 'text': 'unless otherwise '},
#       {'column_index': 7, 'text': 'indicated) '},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 39,
#      'columns': [{'column_index': 1, 'text': 'External sector '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 40,
#      'columns': [{'column_index': 1,
#        'text': 'Total merchandise exports, f.o.b '},
#       {'column_index': 2, 'text': '496.8 '},
#       {'column_index': 3, 'text': '341.5 '},
#       {'column_index': 4, 'text': '281.7 '},
#       {'column_index': 5, 'text': '330.4 '},
#       {'column_index': 6, 'text': '339.1 '},
#       {'column_index': 7, 'text': '349.7 '},
#       {'column_index': 8, 'text': '366.3 '},
#       {'column_index': 9, 'text': '385.2 '},
#       {'column_index': 10, 'text': '412.6 '}]},
#     {'row_index': 41,
#      'columns': [{'column_index': 1,
#        'text': 'Total merchandise imports, f.o.b '},
#       {'column_index': 2, 'text': '-307.9 '},
#       {'column_index': 3, 'text': '-193.0 '},
#       {'column_index': 4, 'text': '-191.7 '},
#       {'column_index': 5, 'text': '-203,1 '},
#       {'column_index': 6, 'text': '-213,7 '},
#       {'column_index': 7, 'text': '-221.9 '},
#       {'column_index': 8, 'text': '-229.4 '},
#       {'column_index': 9, 'text': '-241.6 '},
#       {'column_index': 10, 'text': '-257.6 '}]},
#     {'row_index': 42,
#      'columns': [{'column_index': 1, 'text': 'External current account '},
#       {'column_index': 2, 'text': '57.5 '},
#       {'column_index': 3, 'text': '68,9 '},
#       {'column_index': 4, 'text': '25.0 '},
#       {'column_index': 5, 'text': '44.0 '},
#       {'column_index': 6, 'text': '48.9 '},
#       {'column_index': 7, 'text': '56.6 '},
#       {'column_index': 8, 'text': '63.8 '},
#       {'column_index': 9, 'text': '67.9 '},
#       {'column_index': 10, 'text': '72.2 '}]},
#     {'row_index': 43,
#      'columns': [{'column_index': 1,
#        'text': 'External current account (percent of GDP) '},
#       {'column_index': 2, 'text': '2.8 '},
#       {'column_index': 3, 'text': '5.0 '},
#       {'column_index': 4, 'text': '1.9 '},
#       {'column_index': 5, 'text': '2.9 '},
#       {'column_index': 6, 'text': '3.2 '},
#       {'column_index': 7, 'text': '3.5 '},
#       {'column_index': 8, 'text': '3.8 '},
#       {'column_index': 9, 'text': '3.9 '},
#       {'column_index': 10, 'text': '4.0 '}]},
#     {'row_index': 44,
#      'columns': [{'column_index': 1, 'text': 'Gross international reserves '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 45,
#      'columns': [{'column_index': 1, 'text': 'Billions of U.S. dollars '},
#       {'column_index': 2, 'text': '385.5 '},
#       {'column_index': 3, 'text': '368.4 '},
#       {'column_index': 4, 'text': '377.7 '},
#       {'column_index': 5, 'text': '395.3 '},
#       {'column_index': 6, 'text': '412.6 '},
#       {'column_index': 7, 'text': '427.9 '},
#       {'column_index': 8, 'text': '442.1 '},
#       {'column_index': 9, 'text': '456.4 '},
#       {'column_index': 10, 'text': '469.6 '}]},
#     {'row_index': 46,
#      'columns': [{'column_index': 1, 'text': 'Months of imports 2/ '},
#       {'column_index': 2, 'text': '10.8 '},
#       {'column_index': 3, 'text': '15.7 '},
#       {'column_index': 4, 'text': '17.0 '},
#       {'column_index': 5, 'text': '16.8 '},
#       {'column_index': 6, 'text': '16.7 '},
#       {'column_index': 7, 'text': '16.7 '},
#       {'column_index': 8, 'text': '16.7 '},
#       {'column_index': 9, 'text': '16.3 '},
#       {'column_index': 10, 'text': '15.8 '}]},
#     {'row_index': 47,
#      'columns': [{'column_index': 1, 'text': 'Percent of short-term debt '},
#       {'column_index': 2, 'text': '302 '},
#       {'column_index': 3, 'text': '450 '},
#       {'column_index': 4, 'text': '419 '},
#       {'column_index': 5, 'text': '391 '},
#       {'column_index': 6, 'text': '417 '},
#       {'column_index': 7, 'text': '426 '},
#       {'column_index': 8, 'text': '451 '},
#       {'column_index': 9, 'text': '470 '},
#       {'column_index': 10, 'text': '474 '}]},
#     {'row_index': 48,
#      'columns': [{'column_index': 1, 'text': 'Memorandum items: '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 49,
#      'columns': [{'column_index': 1,
#        'text': 'Nominal GDP (billions of rubles) '},
#       {'column_index': 2, 'text': '79,200 '},
#       {'column_index': 3, 'text': '83,233 '},
#       {'column_index': 4, 'text': '86,044 '},
#       {'column_index': 5, 'text': '92,277 '},
#       {'column_index': 6, 'text': '97,152 '},
#       {'column_index': 7, 'text': '102,598 '},
#       {'column_index': 8, 'text': '108,220 '},
#       {'column_index': 9, 'text': '114,186 '},
#       {'column_index': 10, 'text': '120,452 '}]},
#     {'row_index': 50,
#      'columns': [{'column_index': 1,
#        'text': 'Nominal GDP (billions of U.S. dollars) '},
#       {'column_index': 2, 'text': '2,064 '},
#       {'column_index': 3, 'text': '1,366 '},
#       {'column_index': 4, 'text': '1,283 '},
#       {'column_index': 5, 'text': '1,498 '},
#       {'column_index': 6, 'text': '1,551 '},
#       {'column_index': 7, 'text': '1,602 '},
#       {'column_index': 8, 'text': '1,660 '},
#       {'column_index': 9, 'text': '1,729 '},
#       {'column_index': 10, 'text': '1,787 '}]},
#     {'row_index': 51,
#      'columns': [{'column_index': 1,
#        'text': 'Exchange rate (rubles per U.S. dollar, period average) '},
#       {'column_index': 2, 'text': '38.4 '},
#       {'column_index': 3, 'text': '60.9 '},
#       {'column_index': 4, 'text': '67.1 '},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': '... '},
#       {'column_index': 7, 'text': '... '},
#       {'column_index': 8, 'text': '... '},
#       {'column_index': 9, 'text': '... '},
#       {'column_index': 10, 'text': '... '}]},
#     {'row_index': 52,
#      'columns': [{'column_index': 1,
#        'text': 'Oil exports (billions of U.S. dollars) '},
#       {'column_index': 2, 'text': '269.7 '},
#       {'column_index': 3, 'text': '157.0 '},
#       {'column_index': 4, 'text': '119.8 '},
#       {'column_index': 5, 'text': '141.5 '},
#       {'column_index': 6, 'text': '142.9 '},
#       {'column_index': 7, 'text': '141.9 '},
#       {'column_index': 8, 'text': '144.1 '},
#       {'column_index': 9, 'text': '147.4 '},
#       {'column_index': 10, 'text': '156.5 '}]},
#     {'row_index': 53,
#      'columns': [{'column_index': 1,
#        'text': 'Brent oil price (U.S. dollars per barrel) '},
#       {'column_index': 2, 'text': '98.9 '},
#       {'column_index': 3, 'text': '52.4 '},
#       {'column_index': 4, 'text': '44.0 '},
#       {'column_index': 5, 'text': '52.9 '},
#       {'column_index': 6, 'text': '53.1 '},
#       {'column_index': 7, 'text': '52.8 '},
#       {'column_index': 8, 'text': '53.0 '},
#       {'column_index': 9, 'text': '53.8 '},
#       {'column_index': 10, 'text': '55.0 '}]},
#     {'row_index': 54,
#      'columns': [{'column_index': 1,
#        'text': 'Urals crude oil spot price (U.S. dollars per barrel) '},
#       {'column_index': 2, 'text': '94.5 '},
#       {'column_index': 3, 'text': '51.0 '},
#       {'column_index': 4, 'text': '42.7 '},
#       {'column_index': 5, 'text': '51.5 '},
#       {'column_index': 6, 'text': '51.8 '},
#       {'column_index': 7, 'text': '51.4 '},
#       {'column_index': 8, 'text': '51.6 '},
#       {'column_index': 9, 'text': '52.4 '},
#       {'column_index': 10, 'text': '52.3 '}]},
#     {'row_index': 55,
#      'columns': [{'column_index': 1,
#        'text': 'Oil Extraction (millions of tons) '},
#       {'column_index': 2, 'text': '525.1 '},
#       {'column_index': 3, 'text': '525.0 '},
#       {'column_index': 4, 'text': '525.0 '},
#       {'column_index': 5, 'text': '525.0 '},
#       {'column_index': 6, 'text': '525.0 '},
#       {'column_index': 7, 'text': '525.0 '},
#       {'column_index': 8, 'text': '525.0 '},
#       {'column_index': 9, 'text': '525.0 '},
#       {'column_index': 10, 'text': '525.0 '}]},
#     {'row_index': 56,
#      'columns': [{'column_index': 1,
#        'text': 'Real effective exchange rate (average percent change) '},
#       {'column_index': 2, 'text': '-8.5 '},
#       {'column_index': 3, 'text': '-17.4 '},
#       {'column_index': 4, 'text': '-1.2 '},
#       {'column_index': 5, 'text': '... '},
#       {'column_index': 6, 'text': '... '},
#       {'column_index': 7, 'text': '... '},
#       {'column_index': 8, 'text': '... '},
#       {'column_index': 9, 'text': '... '},
#       {'column_index': 10, 'text': '... '}]}]}],
#  33: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '(Billions of U.S. '},
#       {'column_index': 3, 'text': 'dollars, unless '},
#       {'column_index': 4, 'text': 'otherwise '},
#       {'column_index': 5, 'text': 'indicated) '},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '2014 '},
#       {'column_index': 3, 'text': '2015 '},
#       {'column_index': 4, 'text': '2016 '},
#       {'column_index': 5, 'text': '2017 '},
#       {'column_index': 6, 'text': '2018 '},
#       {'column_index': 7, 'text': '2019 '},
#       {'column_index': 8, 'text': '2020 '},
#       {'column_index': 9, 'text': '2021 '},
#       {'column_index': 10, 'text': '2022 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': 'Projection '},
#       {'column_index': 8, 'text': ''},
#       {'column_index': 9, 'text': ''},
#       {'column_index': 10, 'text': ''}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': 'Current Account '},
#       {'column_index': 2, 'text': '57.5 '},
#       {'column_index': 3, 'text': '68,9 '},
#       {'column_index': 4, 'text': '25.0 '},
#       {'column_index': 5, 'text': '44.0 '},
#       {'column_index': 6, 'text': '48.9 '},
#       {'column_index': 7, 'text': '56.6 '},
# ...
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Macroprudential Policy '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1,
#        'text': 'Adopt legal changes to provide a comprehensive policy toolkit (CBR, MoF). '},
#       {'column_index': 2, 'text': 'ST/MT '},
#       {'column_index': 3,
#        'text': "In progress. The CBR is drafting a regulation to consolidate existing macroprudential tools. The authorities have taken measures to reduce dollarization by requiring higher capital risk weights on banks' FX lending not matched by FX earnings. "}]},
#     {'row_index': 7,
#      'columns': [{'column_index': 1,
#        'text': 'Crisis Management and Resolution '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''}]},
#     {'row_index': 8,
#      'columns': [{'column_index': 1,
#        'text': 'Review the framework for the use of public funds to finance the DIA for resolution purposes to be provided by the federal government. If necessary to use CBR funds, the federal government should provide an indemnity (CBR, MoF). '},
#       {'column_index': 2, 'text': 'MT '},
#       {'column_index': 3,
#        'text': 'Not done. The authorities have identified a new mechanism to finance the costs of banking resolution but it does not explicitly provide for use of public funds. '}]},
#     {'row_index': 9,
#      'columns': [{'column_index': 1,
#        'text': 'Establish a funding mechanism for recovery of the costs of providing temporary public financing through levies on the financial industry (CBR, MoF). '},
#       {'column_index': 2, 'text': 'MT '},
#       {'column_index': 3,
#        'text': 'Not done. The resolution mechanism does not envisage levies on banks other than the premia already collected by the DIA. '}]},
#     {'row_index': 10,
#      'columns': [{'column_index': 1,
#        'text': 'Introduce the full range of resolution powers and safeguards recommended by the FSB Key Attributes, including by implementing legal and operational changes needed to make purchase and assumption (P&A) an effective resolution tool (CBR, MoF). '},
#       {'column_index': 2, 'text': 'ST '},
#       {'column_index': 3,
#        'text': 'In progress. The authorities have introduced a new resolution mechanism. However, there is no provision as yet for asset transfer at market prices to an acquiring institution as part of a P&A transaction. '}]},
#     {'row_index': 11,
#      'columns': [{'column_index': 1, 'text': 'Banking Sector Development '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''}]},
#     {'row_index': 12,
#      'columns': [{'column_index': 1,
#        'text': "Promote legal reforms to increase state-owned commercial banks (SOB's) Board effectiveness (MoF, CBR). "},
#       {'column_index': 2, 'text': 'MT '},
#       {'column_index': 3, 'text': 'Not done. '}]},
#     {'row_index': 13,
#      'columns': [{'column_index': 1,
#        'text': 'Continue gradual privatization of SOBs (MoF, CBR) as conditions permit. '},
#       {'column_index': 2, 'text': 'MT '},
#       {'column_index': 3, 'text': 'Not done. '}]},
#     {'row_index': 14,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''}]}]}],
#  51: '<b> NO Table FOUND </b>',
#  52: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': 'General Resources Account '},
#       {'column_index': 2, 'text': 'SDR Million '},
#       {'column_index': 3, 'text': 'Percent Quota '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': 'Quota '},
#       {'column_index': 2, 'text': '12,903.70 '},
#       {'column_index': 3, 'text': '100.00 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': 'Fund holdings of currency '},
#       {'column_index': 2, 'text': '11,425.27 '},
#       {'column_index': 3, 'text': '88.54 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': 'Reserve Position '},
#       {'column_index': 2, 'text': '1,478.45 '},
#       {'column_index': 3, 'text': '11.46 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Lending to the Fund '},
#       {'column_index': 2, 'text': '750.66 '},
#       {'column_index': 3, 'text': ''}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1, 'text': 'New Arrangements to Borrow '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''}]}]},
#   {'table_id': 'Table_2',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': 'SDR Department '},
#       {'column_index': 2, 'text': 'SDR Million '},
#       {'column_index': 3, 'text': 'Percent Allocation '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': 'Net cumulative allocation '},
#       {'column_index': 2, 'text': '5,671.80 '},
#       {'column_index': 3, 'text': '100.00 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': 'Holdings '},
#       {'column_index': 2, 'text': '4,823.48 '},
#       {'column_index': 3, 'text': '85.04 '}]}]},
#   {'table_id': 'Table_3',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': 'Type '},
#       {'column_index': 2, 'text': 'Approval Date '},
#       {'column_index': 3, 'text': 'Expiration Date '},
#       {'column_index': 4, 'text': 'Amount Approved (SDR million) '},
#       {'column_index': 5, 'text': 'Amount Drawn (SDR million) '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': 'Stand-by '},
#       {'column_index': 2, 'text': '07/28/99 '},
#       {'column_index': 3, 'text': '12/27/00 '},
#       {'column_index': 4, 'text': '3,300.00 '},
#       {'column_index': 5, 'text': '471.43 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': 'EFF '},
#       {'column_index': 2, 'text': '03/26/96 '},
#       {'column_index': 3, 'text': '03/26/99 '},
#       {'column_index': 4, 'text': '13,206.57 '},
#       {'column_index': 5, 'text': '5,779.71 '}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': 'Of which SRF '},
#       {'column_index': 2, 'text': '07/20/98 '},
#       {'column_index': 3, 'text': '03/26/99 '},
#       {'column_index': 4, 'text': '3,992.47 '},
#       {'column_index': 5, 'text': '675.02 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Stand-by '},
#       {'column_index': 2, 'text': '04/11/95 '},
#       {'column_index': 3, 'text': '03/26/96 '},
#       {'column_index': 4, 'text': '4,313.10 '},
#       {'column_index': 5, 'text': '4,313.10 '}]}]},
#   {'table_id': 'Table_4',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': 'Forthcoming '},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': '2017 '},
#       {'column_index': 3, 'text': '2018 '},
#       {'column_index': 4, 'text': '2019 '},
#       {'column_index': 5, 'text': '2020 '},
#       {'column_index': 6, 'text': '2021 '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': 'Principal '},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': ''},
#       {'column_index': 6, 'text': ''}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1, 'text': 'Charges/Interest '},
#       {'column_index': 2, 'text': '2.70 '},
#       {'column_index': 3, 'text': '3.68 '},
#       {'column_index': 4, 'text': '3.68 '},
#       {'column_index': 5, 'text': '3.68 '},
#       {'column_index': 6, 'text': '3.68 '}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Total '},
#       {'column_index': 2, 'text': '2.70 '},
#       {'column_index': 3, 'text': '3.68 '},
#       {'column_index': 4, 'text': '3.68 '},
#       {'column_index': 5, 'text': '3.68 '},
#       {'column_index': 6, 'text': '3.68 '}]}]}],
#  53: '<b> NO Table FOUND </b>',
#  54: '<b> NO Table FOUND </b>',
#  55: '<b> NO Table FOUND </b>',
#  56: '<b> NO Table FOUND </b>',
#  57: [{'table_id': 'Table_1',
#    'rows': [{'row_index': 1,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': 'Date of latest observation '},
#       {'column_index': 3, 'text': 'Date received '},
#       {'column_index': 4, 'text': 'Frequency of Data '},
#       {'column_index': 5, 'text': 'Frequency of '},
#       {'column_index': 6, 'text': 'Frequency of Publication '},
#       {'column_index': 7, 'text': 'Memo '},
#       {'column_index': 8, 'text': 'Items: '}]},
#     {'row_index': 2,
#      'columns': [{'column_index': 1, 'text': ''},
#       {'column_index': 2, 'text': ''},
#       {'column_index': 3, 'text': ''},
#       {'column_index': 4, 'text': ''},
#       {'column_index': 5, 'text': 'Reporting '},
#       {'column_index': 6, 'text': ''},
#       {'column_index': 7, 'text': 'Data Quality - Methodologic al soundness '},
#       {'column_index': 8,
#        'text': 'Data Quality - Accuracy and reliability '}]},
#     {'row_index': 3,
#      'columns': [{'column_index': 1, 'text': 'Exchange Rates '},
#       {'column_index': 2, 'text': 'April 2017 '},
#       {'column_index': 3, 'text': '5/13/2017 '},
#       {'column_index': 4, 'text': 'D '},
#       {'column_index': 5, 'text': 'D '},
#       {'column_index': 6, 'text': 'D '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 4,
#      'columns': [{'column_index': 1,
#        'text': 'International Reserve Assets and Reserve Liabilities of the Monetary Authorities 1 '},
#       {'column_index': 2, 'text': 'April 2017 '},
#       {'column_index': 3, 'text': '5/13/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 5,
#      'columns': [{'column_index': 1, 'text': 'Reserve/Base Money '},
#       {'column_index': 2, 'text': 'March 2017 '},
#       {'column_index': 3, 'text': '5/15/2017 '},
#       {'column_index': 4, 'text': 'D '},
#       {'column_index': 5, 'text': 'W '},
#       {'column_index': 6, 'text': 'W '},
#       {'column_index': 7, 'text': 'O, O, LO, LO '},
#       {'column_index': 8, 'text': 'O, O, O, O, o '}]},
#     {'row_index': 6,
#      'columns': [{'column_index': 1, 'text': 'Broad Money '},
#       {'column_index': 2, 'text': 'March 2017 '},
#       {'column_index': 3, 'text': '5/15/2017 '},
#       {'column_index': 4, 'text': 'D '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'O,O,LO,LO '},
#       {'column_index': 8, 'text': '0,0,0,0,0 '}]},
#     {'row_index': 7,
#      'columns': [{'column_index': 1, 'text': 'Central Bank Balance Sheet '},
#       {'column_index': 2, 'text': 'March 2017 '},
#       {'column_index': 3, 'text': '5/15/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'O,O,LO,LO '},
#       {'column_index': 8, 'text': '0,0,0,0,0 '}]},
#     {'row_index': 8,
#      'columns': [{'column_index': 1,
#        'text': 'Consolidated Balance Sheet of the Banking System '},
#       {'column_index': 2, 'text': 'March 2017 '},
#       {'column_index': 3, 'text': '5/15/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'O,O,LO,LO '},
#       {'column_index': 8, 'text': '0,0,0,0,0 '}]},
#     {'row_index': 9,
#      'columns': [{'column_index': 1, 'text': 'Interest Rates '},
#       {'column_index': 2, 'text': 'April 2017 '},
#       {'column_index': 3, 'text': '5/15/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'O,O,LO,LO '},
#       {'column_index': 8, 'text': '0,0,0,0,0 '}]},
#     {'row_index': 10,
#      'columns': [{'column_index': 1, 'text': 'Consumer Price Index '},
#       {'column_index': 2, 'text': 'February 2017 '},
#       {'column_index': 3, 'text': '4/12/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 11,
#      'columns': [{'column_index': 1,
#        'text': 'Revenue, Expenditure, Balance and Composition of Financing - General Government4 '},
#       {'column_index': 2, 'text': 'May 2017 '},
#       {'column_index': 3, 'text': '5/18/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'O, LO, LNO, o '},
#       {'column_index': 8, 'text': '0,0,0,0,0 '}]},
#     {'row_index': 12,
#      'columns': [{'column_index': 1,
#        'text': 'Revenue, Expenditure, Balance and Composition of Financing Central Government '},
#       {'column_index': 2, 'text': 'May 2017 '},
#       {'column_index': 3, 'text': '5/18/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': 'LO, LNO, LO, o '},
#       {'column_index': 8, 'text': 'O, O, LO, O, NA '}]},
#     {'row_index': 13,
#      'columns': [{'column_index': 1,
#        'text': 'Stocks of Central Government and Central Government-Guaranteed Debt 5 '},
#       {'column_index': 2, 'text': 'May 2017 '},
#       {'column_index': 3, 'text': '5/18/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 14,
#      'columns': [{'column_index': 1,
#        'text': 'External Current Account Balance '},
#       {'column_index': 2, 'text': '2017Q1 '},
#       {'column_index': 3, 'text': '4/05/2017 '},
#       {'column_index': 4, 'text': 'M '},
#       {'column_index': 5, 'text': 'M '},
#       {'column_index': 6, 'text': 'M '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 15,
#      'columns': [{'column_index': 1,
#        'text': 'Exports and Imports of Goods and Services '},
#       {'column_index': 2, 'text': '2017Q1 '},
#       {'column_index': 3, 'text': '4/05/2017 '},
#       {'column_index': 4, 'text': 'Q '},
#       {'column_index': 5, 'text': 'Q '},
#       {'column_index': 6, 'text': 'Q '},
#       {'column_index': 7, 'text': 'O, O, O,LO '},
#       {'column_index': 8, 'text': 'LO, O, O, O, O '}]},
#     {'row_index': 16,
#      'columns': [{'column_index': 1, 'text': 'GDP/GNP '},
#       {'column_index': 2, 'text': '2016Q4 '},
#       {'column_index': 3, 'text': '5/13/2017 '},
#       {'column_index': 4, 'text': 'Q '},
#       {'column_index': 5, 'text': 'Q '},
#       {'column_index': 6, 'text': 'Q '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]},
#     {'row_index': 17,
#      'columns': [{'column_index': 1, 'text': 'Gross External Debt '},
#       {'column_index': 2, 'text': '2017Q1 '},
#       {'column_index': 3, 'text': '5/14/2017 '},
#       {'column_index': 4, 'text': 'Q '},
#       {'column_index': 5, 'text': 'Q '},
#       {'column_index': 6, 'text': 'Q '},
#       {'column_index': 7, 'text': 'O, O, O, o '},
#       {'column_index': 8, 'text': 'O, O,LO, O, LO '}]},
#     {'row_index': 18,
#      'columns': [{'column_index': 1,
#        'text': 'International Investment Position 6 '},
#       {'column_index': 2, 'text': '2017Q1 '},
#       {'column_index': 3, 'text': '5/10/2017 '},
#       {'column_index': 4, 'text': 'Q '},
#       {'column_index': 5, 'text': 'Q '},
#       {'column_index': 6, 'text': 'Q '},
#       {'column_index': 7, 'text': ''},
#       {'column_index': 8, 'text': ''}]}]}]}

# %% [markdown]
# ## Misc Experiments (Ignore)

# %%
access_key = ""
secret_key = ""
region = ''

client = boto3.client('textract')


#ppm_img_file = image_to_byte_array(images_list[10])

#imgByteArr = io.BytesIO()
#ppm_img_file.save(imgByteArr, format=ppm_img_file.format)
#imgByteArr = imgByteArr.getvalue()

#stream = io.BytesIO(ppm_img_file)
#image=Image.open(stream)

# Analyze the document
#image_binary = ppm_img_file.tobytes()

response = client.analyze_document(
    Document={
        'Bytes': byte_im,
    },
    FeatureTypes=['TABLES']
)
